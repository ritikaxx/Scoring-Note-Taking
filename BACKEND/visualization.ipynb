# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('../input/nbme-score-clinical-patient-notes'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../input/nbme-score-clinical-patient-notes\features.csv
# ../input/nbme-score-clinical-patient-notes\patient_notes.csv
# ../input/nbme-score-clinical-patient-notes\sample_submission.csv
# ../input/nbme-score-clinical-patient-notes\test.csv
# ../input/nbme-score-clinical-patient-notes\train.csv

# %%
import numpy as np
import pandas as pd 
import os
import re
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import textstat
import spacy
nlp = spacy.load('en_core_web_sm')

from termcolor import colored
from wordcloud import WordCloud,STOPWORDS
from spacy import displacy
from nltk.tokenize import sent_tokenize, word_tokenize 

import warnings
warnings.filterwarnings("ignore")

# %%
patient_notes = pd.read_csv('../input/nbme-score-clinical-patient-notes/patient_notes.csv')
features = pd.read_csv('../input/nbme-score-clinical-patient-notes/features.csv')
train = pd.read_csv('../input/nbme-score-clinical-patient-notes/train.csv')

# %%
patient_notes.head()
# Out:
#    pn_num  case_num                                         pn_history
# 0       0         0  17-year-old male, has come to the student heal...
# 1       1         0  17 yo male with recurrent palpitations for the...
# 2       2         0  Dillon Cleveland is a 17 y.o. male patient wit...
# 3       3         0  a 17 yo m c/o palpitation started 3 mos ago; \...
# 4       4         0  17yo male with no pmh here for evaluation of p...

# %%
patient_notes['pn_history'][0]
# Out:
# "17-year-old male, has come to the student health clinic complaining of heart pounding. Mr. Cleveland's mother has given verbal consent for a history, physical examination, and treatment\r\n-began 2-3 months ago,sudden,intermittent for 2 days(lasting 3-4 min),worsening,non-allev/aggrav\r\n-associated with dispnea on exersion and rest,stressed out about school\r\n-reports fe feels like his heart is jumping out of his chest\r\n-ros:denies chest pain,dyaphoresis,wt loss,chills,fever,nausea,vomiting,pedal edeam\r\n-pmh:non,meds :aderol (from a friend),nkda\r\n-fh:father had MI recently,mother has thyroid dz\r\n-sh:non-smoker,mariguana 5-6 months ago,3 beers on the weekend, basketball at school\r\n-sh:no std"

# %%
features.head()
# Out:
#    feature_num  case_num                                       feature_text
# 0            0         0  Family-history-of-MI-OR-Family-history-of-myoc...
# 1            1         0                 Family-history-of-thyroid-disorder
# 2            2         0                                     Chest-pressure
# 3            3         0                              Intermittent-symptoms
# 4            4         0                                        Lightheaded

# %%
train.head()
# Out:
#           id  case_num  pn_num  feature_num  \
# 0  00016_000         0      16            0
# 1  00016_001         0      16            1
# 2  00016_002         0      16            2
# 3  00016_003         0      16            3
# 4  00016_004         0      16            4
#
#                                  annotation              location
# 0          ['dad with recent heart attcak']           ['696 724']
# 1             ['mom with "thyroid disease']           ['668 693']
# 2                        ['chest pressure']           ['203 217']
# 3      ['intermittent episodes', 'episode']  ['70 91', '176 183']
# 4  ['felt as if he were going to pass out']           ['222 258']

# %%
features.nunique()
# Out:
# feature_num     143
# case_num         10
# feature_text    131
# dtype: int64

# %%
patient_notes.nunique()
# Out:
# pn_num        42146
# case_num         10
# pn_history    42146
# dtype: int64

# %%
train.nunique()
# Out:
# id             14300
# case_num          10
# pn_num          1000
# feature_num      143
# annotation      5201
# location        7534
# dtype: int64

# %%
def patient_data(pn_num):
    subset = train[train['pn_num'] == pn_num]
    
    features_lst = subset['feature_num'].tolist()
    annotations_lst = subset['annotation'].tolist()
    
    subset_c = subset.copy()
    subset_c['location'] = subset_c['location'].apply(eval)
    subset_c['annotation'] = subset_c['annotation'].apply(eval)
    locations  = subset_c["location"]
    annotations = subset_c["annotation"]
    
    print("*"*80)
    print(colored("Patient Number: " + str(pn_num), 'green'))
    patient_history = patient_notes[patient_notes['pn_num']==pn_num]['pn_history'].item()
    
    print(colored("\nAnnotated Patient History", 'green'))
    
    ents = []
    for location in locations:
        for i in range(len(location)):
            for loc in location:
                val = loc.split()
                ents.append({
                'start': int(val[0]), 
                'end' :  int(val[1]),
                'label' : "Annotation"
                })
    ents = sorted(ents, key = lambda i: i['start'])

    doc = {
        'text' : patient_history,
        'ents' : ents
    }
    colors = {"Annotation" :"linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);" } 
    options = {"colors": colors}
    spacy.displacy.render(doc, style='ent', options = options , manual=True, jupyter=True);
    
    print(colored("\nVisualizing NER", 'green'))
    doc = nlp(patient_history)
    displacy.render(doc, style='ent', jupyter = True)
    
    """print(colored("\nVisualizing POS tagging", 'green'))
    sentences = sent_tokenize(patient_history)
    word_count = lambda sentence: len(word_tokenize(sentence))
    pos_text = max(sentences, key=word_count)  
    doc = nlp(pos_text)
    displacy.render(doc, style="dep")"""

    print(colored("\nFeatures", 'green'))
    for feature_num in features_lst:
        feature = features[features['feature_num'] == feature_num]['feature_text'][feature_num]
        print(colored(feature, 'blue'))
        
patient_data(352)
patient_data(46)
patient_data(100)
# Out:
# ********************************************************************************
# Patient Number: 352
#
# Annotated Patient History
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Dillon Cleveland is a
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17yo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  otherwise healthy
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  presenting with 5-6 episodes of
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  within the
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     duration of past 3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# . 2 days ago, the patient also experience a
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest tightness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest tightness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  during basketball and was relieved by rest. Basketball seemed to have made the
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest tightness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest tightness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  come on, but the palpitations have no associated trigger, and both are relieved by rest and resolves on its own. Patient endorses
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     using Adderall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# </br>FH:
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mother with &quot;thyroid&quot;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  and
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     father with heart attack recently
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     father with heart attack
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     father with heart attack recently
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     father with heart attack
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  recently</div></span>
# Visualizing NER
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dillon Cleveland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a 17yo otherwise healthy M presenting with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -6 episodes of palpitations within the duration of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     past 3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 days ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the patient also experience a chest tightness during basketball and was relieved by rest. Basketball seemed to have made the chest tightness come on, but the palpitations have no associated trigger, and both are relieved by rest and resolves on its own. Patient endorses using
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adderall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>PMH:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     None
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PSH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     None
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adderall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Allergies:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NKDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>SH: Freshman in college as a 17yo majoring in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Philosophy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Drinking on the weekends
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>FH: Mother with &quot;thyroid&quot; and father with heart attack recently</div></span>
# Features
# Family-history-of-MI-OR-Family-history-of-myocardial-infarction
# Family-history-of-thyroid-disorder
# Chest-pressure
# Intermittent-symptoms
# Lightheaded
# No-hair-changes-OR-no-nail-changes-OR-no-temperature-intolerance
# Adderall-use
# Shortness-of-breath
# Caffeine-use
# heart-pounding-OR-heart-racing
# Few-months-duration
# 17-year
# Male
# ********************************************************************************
# Patient Number: 46
#
# Annotated Patient History
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr. Cleveland is a
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17yo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  who was consented by parents to be alone today and provide information.  He has no notable PMH and presented today with
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  that have been occurring
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sporadically
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     for 2-3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# .  He started college 7-8 months ago and described feelings of nervousness and anxiousness with starting school and exams.  He endorses using his roommates prescription
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adderall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adderall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  to study for tests and this coincides with the
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  at times.  Nothing makes his
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  worse or better when they occur.  ROS is negative except for
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     light headedness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  and
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SOB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# .  He
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     has not had any cold/heat intolerance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# </br>Meds:
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adderall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adderall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# </br>Family:
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mom: thyroid issues
#     <span style="font-siz
# Visualizing NER
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cleveland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is a 17yo M who was consented by parents to be alone
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and provide information.  He has no notable
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PMH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and presented
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with palpitations that have been occurring sporadically for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2-3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .  He started college
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7-8 months ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and described feelings of nervousness and anxiousness with starting school and exams.  He endorses using his roommates prescription adderall to study for tests and this coincides with the palpitations at times.  Nothing makes his palpitations worse or better when they occur.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ROS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is negative except for light headedness and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SOB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PMH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PSH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>All:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NKDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>social:  no tob,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     occ EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>exercise:  basketball</div></span>
# Features
# Family-history-of-MI-OR-Family-history-of-myocardial-infarction
# Family-history-of-thyroid-disorder
# Chest-pressure
# Intermittent-symptoms
# Lightheaded
# No-hair-changes-OR-no-nail-changes-OR-no-temperature-intolerance
# Adderall-use
# Shortness-of-breath
# Caffeine-use
# heart-pounding-OR-heart-racing
# Few-months-duration
# 17-year
# Male
# ********************************************************************************
# Patient Number: 100
#
# Annotated Patient History
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">HPI: Dillon Cleveland is an otherwise healthy
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17 year old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     male
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  presenting due to rapid
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pounding heart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pounding heart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  rate for
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2-3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2-3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# . He has never experienced these symptoms before. Comes on randomly, nothing makes it better. Lasts 3-4 minutes. Has happened
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5-6 times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  over last
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2-3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2-3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# </br>-Endorses
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     light headedness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# ,
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest pressure
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# </br>-Intermittent tachycardia and
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pounding heart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pounding heart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# </br>PMH: no medical issues, no allergies, takes friend's
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adderall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# </br>FAM:
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mom-thyroid problem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
# ,
# <mark class="entity" style="background: linear-gradient(to right, #2980b9, #6dd5fa, #ffffff);; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dad-MI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Annotation</span>
# </mark>
#  last year</div></span>
# Visualizing NER
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">HPI: Dillon
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cleveland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is an otherwise healthy
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     17 year old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  male presenting due to rapid pounding heart rate for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2-3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . He has never experienced these symptoms before. Comes on randomly, nothing makes it better. Lasts
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3-4 minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# . Has happened
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -6 times over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last 2-3 months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ROS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : as per
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HPI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PMH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SOC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : No tobacco use,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  use
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FAM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : Mom-thyroid problem, Dad-MI
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>
# Features
# Family-history-of-MI-OR-Family-history-of-myocardial-infarction
# Family-history-of-thyroid-disorder
# Chest-pressure
# Intermittent-symptoms
# Lightheaded
# No-hair-changes-OR-no-nail-changes-OR-no-temperature-intolerance
# Adderall-use
# Shortness-of-breath
# Caffeine-use
# heart-pounding-OR-heart-racing
# Few-months-duration
# 17-year
# Male

# %%
def color_wc(word=None,font_size=None,position=None, orientation=None,font_path=None, random_state=None):
    h = int(360.0 * 150.0 / 255.0)
    s = int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(80, 120)) / 255.0)
    return "hsl({}, {}%, {}%)".format(h, s, l)

def create_wordcloud(df, col):
    print(colored(col, 'green'))
    plt.subplots(figsize=(16,16))
    wc = WordCloud(stopwords=STOPWORDS,background_color="white", contour_width=2, contour_color='blue',width=1500, height=750,color_func=color_wc,max_words=150, max_font_size=256,random_state=42)
    wc.generate(' '.join(df[col]))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis('off')
    plt.show()
    
create_wordcloud(train, 'annotation')
create_wordcloud(features, 'feature_text')
create_wordcloud(patient_notes, 'pn_history')
# Out:
# annotation
# feature_text
# pn_history

# %%
def patient_data(pn_num):
    subset = train[train['pn_num'] == pn_num]
    
    features_lst = subset['feature_num'].tolist()
    annotations_lst = subset['annotation'].tolist()
    
    subset_c = subset.copy()
    subset_c['location'] = subset_c['location'].apply(eval)
    subset_c['annotation'] = subset_c['annotation'].apply(eval)
    locations  = subset_c["location"]
    annotations = subset_c["annotation"]
    
    print("*"*80)
    print(colored("Patient Number: " + str(pn_num), 'green'))
    patient_history = patient_notes[patient_notes['pn_num']==pn_num]['pn_history'].item()
    
    for feature_num in features_lst:
        feature = features[features['feature_num'] == feature_num]['feature_text'][feature_num]
        
        print(feature)

# %%
patient_data(46)
# Out:
# ********************************************************************************
# Patient Number: 46
# Family-history-of-MI-OR-Family-history-of-myocardial-infarction
# Family-history-of-thyroid-disorder
# Chest-pressure
# Intermittent-symptoms
# Lightheaded
# No-hair-changes-OR-no-nail-changes-OR-no-temperature-intolerance
# Adderall-use
# Shortness-of-breath
# Caffeine-use
# heart-pounding-OR-heart-racing
# Few-months-duration
# 17-year
# Male
